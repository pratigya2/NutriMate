# %%
import pandas  as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import NearestNeighbors

import numpy as np

# %%
feature = pd.read_csv(DATA)
X = feature.iloc[:, [1,2,3,6]].values
Y = feature.iloc[:, :1].values
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11160/952650437.py in <module>
# ----> 1 feature = pd.read_csv(DATA)
#       2 X = feature.iloc[:, [1,2,3,6]].values
#       3 Y = feature.iloc[:, :1].values
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     948     kwds.update(kwds_defaults)
#     949
# --> 950     return _read(filepath_or_buffer, kwds)
#     951
#     952
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     603
#     604     # Create the parser.
# --> 605     parser = TextFileReader(filepath_or_buffer, **kwds)
#     606
#     607     if chunksize or iterator:
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#    1440
#    1441         self.handles: IOHandles | None = None
# -> 1442         self._engine = self._make_engine(f, self.engine)
#    1443
#    1444     def close(self) -> None:
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, f, engine)
#    1733                 if "b" not in mode:
#    1734                     mode += "b"
# -> 1735             self.handles = get_handle(
#    1736                 f,
#    1737                 mode,
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854         if ioargs.encoding and "b" not in ioargs.mode:
#     855             # Encoding
# --> 856             handle = open(
#     857                 handle,
#     858                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/kaggle/input/nepali-meals-dataset/meals.csv'

# %%
feature.head()
# Out:
#      Nepali Food Name  Gluten-Free  Sugar-Free  Keto  Vegetarian  Dairy-Free  \
# 0  Adad Daal (Lentil)          0.8         1.0   0.2           1           1
# 1      Almond Pudding          0.6         0.5   0.3           0           1
# 2           Aloo Tama          0.8         0.5   0.4           0           0
# 3        Avocado Momo          0.6         0.2   0.3           0           0
# 4                Baji          0.9         0.2   0.1           0           0
#
#    Paleo  Oil-Free
# 0    0.5         1
# 1    0.4         1
# 2    0.6         1
# 3    0.3         0
# 4    0.6         1

# %%
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# scaler.fit(X_train)

# %% [markdown]
# **Training the Date**

# %%
model = NearestNeighbors(n_neighbors = 25, algorithm ='brute', metric = 'euclidean')
model.fit(X)
# Out:
# NearestNeighbors(algorithm='brute', metric='euclidean', n_neighbors=50)

# %%
new = [1,0,0,0,0,0,0]
input = new[0:3]
input.append(new[5])
input = [input]
dis, indices = model.kneighbors(input)

for value in indices[0]:
  print(Y[value])
# Out:
# ['Shrimp Momo']
# ['Chhurpi']
# ['Buff Momos']
# ['Chow Mein']
# ['Chilka Moong Daal (Split Mung Bean)']
# ['Chapati']
# ['Broccoli Momo']
# ['Carrot Pudding']
# ['Cauliflower Momo']
# ['Cashew Pudding']
# ['Avocado Momo']
# ['Corn Momo']
# ['Bhakka']
# ['Baji']
# ['Potato Pudding']
# ['Chickpea Flour Pudding']
# ['Chicken Choyla']
# ['Chiura']
# ['Dal Bhat Tarkari']
# ['Paratha']
# ['Chana Masala']
# ['Pumpkin Momo']
# ['Sel Puri']
# ['Semolina Pudding']
# ['Sel Roti']
# ['Masyaura Daal (Mixed Lentil)']
# ['Chatamari']
# ['Chana Daal (Split Bengal Gram)']
# ['Bhutun']
# ['Dhido Ra Gundruk']
# ['Sadeko']
# ['Vegetable Biryani']
# ['Palak Paneer']
# ['Baingan Bharta']
# ['Buckwheat Momo']
# ['Chatpate']
# ['Almond Pudding']
# ['Chicken Korma']
# ['Butter Chicken']
# ['Potato Momo']
# ['Jeri Swari']
# ['Janta Roti']
# ['Jau Roti']
# ['Sikkim Thali']
# ['Chicken Momo']
# ['Aloo Gobi']
# ['Saag Aloo']
# ['Cream of Mushroom Soup']
# ['Paneer Tikka']
# ['Aloo Tikki']

# %% [markdown]
# # Saving Model

# %%
import pickle
file = 'model.pk'

with open(file, 'wb') as f:
  pickle.dump(model, f)

f.close()

# %% [markdown]
# # Prediction

# %%
#Prediction
data = '/kaggle/input/nepali-meals-dataset/meals.csv'
df = pd.read_csv(data)

#u_input -> 2D
#user_input-> 1D
#input-> only features to model 

def recommend_meal(u_input):
    saved_model = 'model.pk'
    meals = df.iloc[:, :1].values
    recommendation = list()
    
    
    input = u_input[0:3]
    input.append(u_input[5])
    input = [input]

    with open(saved_model, 'rb') as f :
        loaded_model = pickle.load(f)
        dis, indices = loaded_model.kneighbors(input)

    for value in indices[0]:
      recommendation.append(meals[value])

    r = np.array(recommendation)
    r = r.flatten()
    
    recommendations = df.loc[df['Nepali Food Name'].isin(r)]
    
#     #Using the filters
    user_input = u_input
    if(user_input[3]==0.5):
        r1 = recommendations
    else:
        r1 = recommendations[recommendations['Vegetarian']==user_input[3]]

    if (user_input[4]==0.5):
        r2=r1
    else:
        r2 = r1[r1['Dairy-Free']==user_input[4]]

    if (user_input[6]==0.5):
        r3=r2
    else:
        r3 = r2[r2['Oil-Free']==user_input[6]]

    return r3

# %%
recommend_meal([1,0,0,1,1,1,0.5])
# Out:
#                 Nepali Food Name  Gluten-Free  Sugar-Free  Keto  Vegetarian  \
# 9                         Bhutun          0.9         0.5   0.2           1
# 11                Buckwheat Momo          1.0         0.2   0.3           1
# 13                   Carrot Momo          1.0         0.5   0.4           1
# 14                Carrot Pudding          0.7         0.2   0.2           1
# 19                       Chapati          0.7         0.2   0.3           1
# 20                     Chatamari          0.9         0.5   0.2           1
# 22                   Cheese Momo          0.9         0.2   0.3           1
# 25                Chicken Choyla          0.7         0.2   0.3           1
# 26                  Chicken Momo          1.0         0.2   0.2           1
# 27        Chickpea Flour Pudding          0.7         0.2   0.3           1
# 30                        Chiura          0.8         0.2   0.2           1
# 33                Daal Bhat Roti          1.0         0.5   0.4           1
# 34              Dal Bhat Tarkari          0.9         0.2   0.3           1
# 35              Dhido Ra Gundruk          1.0         0.2   0.2           1
# 41                    Janta Roti          1.0         0.2   0.4           1
# 42                      Jau Roti          1.0         0.2   0.4           1
# 43                         Jaulo          0.4         0.1   0.3           1
# 44                    Jeri Swari          1.0         0.2   0.4           1
# 45                       Kachori          0.5         0.2   0.5           1
# 46      Kalo Daal (Black Lentil)          0.9         0.2   0.4           1
# 47                         Kheer          1.0         0.2   0.4           1
# 48                  Kinema Curry          1.0         0.2   0.5           1
# 57  Masyaura Daal (Mixed Lentil)          0.9         0.5   0.2           1
# 58                    Missi Roti          0.9         0.2   0.4           1
# 59        Moong Daal (Mung Bean)          1.0         0.1   0.3           1
# 60             Mung Bean Pudding          1.0         0.1   0.3           1
# 62                          Naan          0.5         0.1   0.4           1
# 63                   Paneer Momo          0.9         0.2   0.4           1
# 65                Phapar Ko Roti          0.9         0.2   0.4           1
# 66                        Phulka          0.9         0.2   0.4           1
# 68                   Potato Momo          0.9         0.1   0.4           1
# 69                Potato Pudding          0.7         0.1   0.3           1
# 70                  Pumpkin Momo          0.5         0.1   0.3           1
# 71                          Puri          0.9         0.2   0.4           1
# 72                   Quinoa Momo          0.9         0.2   0.4           1
# 73      Rajma Daal (Kidney Bean)          0.9         0.2   0.4           1
# 74                   Rumali Roti          0.9         0.2   0.4           1
# 75                        Sadeko          0.9         0.1   0.3           1
# 76                    Samay Baji          0.9         0.2   0.4           1
# 78                    Sanyakhuna          1.0         0.1   0.5           1
# 79                        Sekuwa          1.0         0.1   0.5           1
#
#     Dairy-Free  Paleo  Oil-Free
# 9            1    0.5         1
# 11           1    0.7         1
# 13           1    0.7         1
# 14           1    0.4         1
# 19           1    0.3         1
# 20           1    0.5         0
# 22           1    0.8         0
# 25           1    0.5         0
# 26           1    0.8         0
# 27           1    0.5         1
# 30           1    0.6         1
# 33           1    0.7         1
# 34           1    0.6         1
# 35           1    0.7         1
# 41           1    0.7         1
# 42           1    0.7         1
# 43           1    0.6         1
# 44           1    0.7         0
# 45           1    0.6         0
# 46           1    0.8         1
# 47           1    0.9         1
# 48           1    0.8         0
# 57           1    0.5         1
# 58           1    0.8         1
# 59           1    0.9         1
# 60           1    0.9         1
# 62           1    0.7         0
# 63           1    0.8         0
# 65           1    0.8         1
# 66           1    0.8         1
# 68           1    0.7         0
# 69           1    0.5         0
# 70           1    0.4         0
# 71           1    0.8         0
# 72           1    0.8         0
# 73           1    0.8         1
# 74           1    0.8         1
# 75           1    0.7         1
# 76           1    0.8         1
# 78           1    1.0         1
# 79           1    1.0         0

# %%
recommendations = df.loc[df['Nepali Food Name'].isin(r)]

# %%
#Split on Veg 
user_input = np.array(user_input).flatten()
if(user_input[4]==0.5):
    pass
else:
    r1 = recommendations[recommendations['Vegetarian']==user_input[4]]
    
if (user_input[5]==0.5):
    pass
else:
    r2 = r1[r1['Dairy-Free']==user_input[5]]
    
if (user_input[7]==0.5):
    pass
else:
    r2 = r1[r1['Dairy-Free']==user_input[7]]

# %%
df.head()
# Out:
#      Nepali Food Name  Gluten-Free  Sugar-Free  Keto  Vegetarian  Dairy-Free  \
# 0  Adad Daal (Lentil)          0.8         1.0   0.2           1           1
# 1      Almond Pudding          0.6         0.5   0.3           0           1
# 2           Aloo Tama          0.8         0.5   0.4           0           0
# 3        Avocado Momo          0.6         0.2   0.3           0           0
# 4                Baji          0.9         0.2   0.1           0           0
#
#    Paleo  Oil-Free
# 0    0.5         1
# 1    0.4         1
# 2    0.6         1
# 3    0.3         0
# 4    0.6         1
